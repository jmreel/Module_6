# %%
# Import the dependencies.
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
import time
from datetime import datetime

from config import weather_api_key
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
#Perform an API call with the OPenWeatherMap.
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=263a3379c99a14abe8652bf67923a35c

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | kaseda
# Processing Record 3 of Set 1 | sao filipe
# Processing Record 4 of Set 1 | burica
# City not found. Skipping...
# Processing Record 5 of Set 1 | pangnirtung
# Processing Record 6 of Set 1 | pout
# Processing Record 7 of Set 1 | salinas
# Processing Record 8 of Set 1 | gimli
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | muisne
# Processing Record 11 of Set 1 | tura
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | ulaangom
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | naushki
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | longyearbyen
# Processing Record 19 of Set 1 | mar del plata
# Processing Record 20 of Set 1 | eyl
# Processing Record 21 of Set 1 | bud
# Processing Record 22 of Set 1 | namibe
# Processing Record 23 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 1 | nago
# Processing Record 25 of Set 1 | fortuna
# Processing Record 26 of Set 1 | tiverton
# Processing Record 27 of Set 1 | concepcion del oro
# Processing Record 28 of Set 1 | koshurnikovo
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | tiarei
# Processing Record 31 of Set 1 | duncan
# Processing Record 32 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 1 | porlamar
# Processing Record 34 of Set 1 | ayan
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | sur
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | avera
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | saint-georges
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | paita
# Processing Record 45 of Set 1 | coquimbo
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | saint george
# Processing Record 48 of Set 1 | porto santo
# Processing Record 49 of Set 1 | lebu
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | ilulissat
# Processing Record 4 of Set 2 | deputatskiy
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | las palmas
# Processing Record 7 of Set 2 | afsin
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | lavrentiya
# Processing Record 10 of Set 2 | saint-augustin
# Processing Record 11 of Set 2 | kedrovyy
# Processing Record 12 of Set 2 | zyryanka
# Processing Record 13 of Set 2 | angoche
# Processing Record 14 of Set 2 | sitka
# Processing Record 15 of Set 2 | tessalit
# Processing Record 16 of Set 2 | wanaka
# Processing Record 17 of Set 2 | christchurch
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | ancud
# Processing Record 20 of Set 2 | ribeira grande
# Processing Record 21 of Set 2 | tuktoyaktuk
# Processing Record 22 of Set 2 | saint anthony
# Processing Record 23 of Set 2 | karratha
# Processing Record 24 of Set 2 | skelleftea
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 27 of Set 2 | najran
# Processing Record 28 of Set 2 | manokwari
# Processing Record 29 of Set 2 | rawson
# Processing Record 30 of Set 2 | hobart
# Processing Record 31 of Set 2 | rafaela
# Processing Record 32 of Set 2 | port hedland
# Processing Record 33 of Set 2 | mount isa
# Processing Record 34 of Set 2 | binzhou
# Processing Record 35 of Set 2 | college
# Processing Record 36 of Set 2 | turtkul
# City not found. Skipping...
# Processing Record 37 of Set 2 | ostrovnoy
# Processing Record 38 of Set 2 | shimoda
# Processing Record 39 of Set 2 | vaitape
# Processing Record 40 of Set 2 | svetlogorsk
# Processing Record 41 of Set 2 | arraial do cabo
# Processing Record 42 of Set 2 | matara
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | chuy
# Processing Record 45 of Set 2 | prince rupert
# Processing Record 46 of Set 2 | muros
# Processing Record 47 of Set 2 | muroto
# Processing Record 48 of Set 2 | jiazi
# Processing Record 49 of Set 2 | faridan
# City not found. Skipping...
# Processing Record 50 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 3 | busselton
# Processing Record 2 of Set 3 | pevek
# Processing Record 3 of Set 3 | ushtobe
# Processing Record 4 of Set 3 | kailua
# Processing Record 5 of Set 3 | yanam
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | ahuimanu
# Processing Record 8 of Set 3 | arrifes
# Processing Record 9 of Set 3 | bluff
# Processing Record 10 of Set 3 | rocha
# Processing Record 11 of Set 3 | loiza
# Processing Record 12 of Set 3 | norman wells
# Processing Record 13 of Set 3 | havre-saint-pierre
# Processing Record 14 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 15 of Set 3 | reconquista
# Processing Record 16 of Set 3 | fort myers beach
# Processing Record 17 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 19 of Set 3 | geraldton
# Processing Record 20 of Set 3 | ixtapa
# Processing Record 21 of Set 3 | itoman
# Processing Record 22 of Set 3 | saldanha
# Processing Record 23 of Set 3 | clyde river
# Processing Record 24 of Set 3 | sabha
# Processing Record 25 of Set 3 | bengkulu
# Processing Record 26 of Set 3 | fairbanks
# Processing Record 27 of Set 3 | upernavik
# Processing Record 28 of Set 3 | moerai
# Processing Record 29 of Set 3 | mahebourg
# Processing Record 30 of Set 3 | wilmington
# Processing Record 31 of Set 3 | solnechnyy
# Processing Record 32 of Set 3 | bat yam
# Processing Record 33 of Set 3 | sabang
# Processing Record 34 of Set 3 | mangochi
# Processing Record 35 of Set 3 | nuevo progreso
# Processing Record 36 of Set 3 | dingle
# Processing Record 37 of Set 3 | hithadhoo
# Processing Record 38 of Set 3 | mount gambier
# Processing Record 39 of Set 3 | codrington
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 3 | byron bay
# Processing Record 42 of Set 3 | bethel
# Processing Record 43 of Set 3 | guymon
# Processing Record 44 of Set 3 | vostok
# Processing Record 45 of Set 3 | harper
# Processing Record 46 of Set 3 | nizhniy tsasuchey
# Processing Record 47 of Set 3 | lagoa
# Processing Record 48 of Set 3 | cabo san lucas
# Processing Record 49 of Set 3 | areosa
# Processing Record 50 of Set 3 | kwekwe
# Processing Record 1 of Set 4 | kalabo
# Processing Record 2 of Set 4 | kibaya
# Processing Record 3 of Set 4 | amurzet
# Processing Record 4 of Set 4 | khatanga
# Processing Record 5 of Set 4 | mandalgovi
# Processing Record 6 of Set 4 | avarua
# Processing Record 7 of Set 4 | belaya gora
# Processing Record 8 of Set 4 | san quintin
# Processing Record 9 of Set 4 | poum
# Processing Record 10 of Set 4 | quatre cocos
# Processing Record 11 of Set 4 | buala
# Processing Record 12 of Set 4 | leland
# Processing Record 13 of Set 4 | billericay
# Processing Record 14 of Set 4 | waingapu
# Processing Record 15 of Set 4 | sao felix do xingu
# Processing Record 16 of Set 4 | amol
# Processing Record 17 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 4 | oudtshoorn
# Processing Record 19 of Set 4 | caravelas
# Processing Record 20 of Set 4 | carnarvon
# Processing Record 21 of Set 4 | luderitz
# Processing Record 22 of Set 4 | ponta do sol
# Processing Record 23 of Set 4 | husavik
# Processing Record 24 of Set 4 | saint-philippe
# Processing Record 25 of Set 4 | barrow
# Processing Record 26 of Set 4 | planeta rica
# Processing Record 27 of Set 4 | sangar
# Processing Record 28 of Set 4 | magnitka
# Processing Record 29 of Set 4 | port elizabeth
# Processing Record 30 of Set 4 | la ronge
# Processing Record 31 of Set 4 | saint-denis
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | half moon bay
# Processing Record 34 of Set 4 | ikorodu
# Processing Record 35 of Set 4 | tasiilaq
# Processing Record 36 of Set 4 | bambous virieux
# Processing Record 37 of Set 4 | nelson bay
# Processing Record 38 of Set 4 | jonkoping
# Processing Record 39 of Set 4 | mehamn
# Processing Record 40 of Set 4 | lompoc
# Processing Record 41 of Set 4 | constantine
# Processing Record 42 of Set 4 | ergani
# Processing Record 43 of Set 4 | provideniya
# Processing Record 44 of Set 4 | ji-parana
# City not found. Skipping...
# Processing Record 45 of Set 4 | zvishavane
# Processing Record 46 of Set 4 | atar
# Processing Record 47 of Set 4 | orange cove
# Processing Record 48 of Set 4 | anadyr
# Processing Record 49 of Set 4 | richards bay
# Processing Record 50 of Set 4 | maues
# Processing Record 1 of Set 5 | hobyo
# Processing Record 2 of Set 5 | kaeo
# Processing Record 3 of Set 5 | bredasdorp
# Processing Record 4 of Set 5 | namwala
# Processing Record 5 of Set 5 | dhaka
# Processing Record 6 of Set 5 | bonfim
# Processing Record 7 of Set 5 | kruisfontein
# Processing Record 8 of Set 5 | martapura
# Processing Record 9 of Set 5 | ambulu
# Processing Record 10 of Set 5 | san cristobal
# Processing Record 11 of Set 5 | fayetteville
# Processing Record 12 of Set 5 | sambava
# Processing Record 13 of Set 5 | ewa beach
# Processing Record 14 of Set 5 | severo-kurilsk
# Processing Record 15 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 16 of Set 5 | limbang
# Processing Record 17 of Set 5 | bahia honda
# Processing Record 18 of Set 5 | axim
# Processing Record 19 of Set 5 | tuatapere
# Processing Record 20 of Set 5 | wellington
# Processing Record 21 of Set 5 | castilho
# Processing Record 22 of Set 5 | torbay
# Processing Record 23 of Set 5 | arti
# Processing Record 24 of Set 5 | kupang
# Processing Record 25 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 5 | vylgort
# City not found. Skipping...
# Processing Record 27 of Set 5 | sao joao da barra
# Processing Record 28 of Set 5 | dikson
# Processing Record 29 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 5 | caconda
# Processing Record 31 of Set 5 | east london
# Processing Record 32 of Set 5 | novoagansk
# Processing Record 33 of Set 5 | narsaq
# Processing Record 34 of Set 5 | mae sai
# Processing Record 35 of Set 5 | riyadh
# Processing Record 36 of Set 5 | kassala
# Processing Record 37 of Set 5 | togur
# Processing Record 38 of Set 5 | alofi
# Processing Record 39 of Set 5 | barahona
# Processing Record 40 of Set 5 | bonavista
# Processing Record 41 of Set 5 | losino-petrovskiy
# Processing Record 42 of Set 5 | faanui
# Processing Record 43 of Set 5 | kosa
# Processing Record 44 of Set 5 | linxia
# Processing Record 45 of Set 5 | oranjemund
# Processing Record 46 of Set 5 | dukat
# Processing Record 47 of Set 5 | nsanje
# Processing Record 48 of Set 5 | sistranda
# Processing Record 49 of Set 5 | miri
# Processing Record 50 of Set 5 | hami
# Processing Record 1 of Set 6 | tahta
# Processing Record 2 of Set 6 | lasa
# Processing Record 3 of Set 6 | yar-sale
# Processing Record 4 of Set 6 | candido mendes
# Processing Record 5 of Set 6 | athabasca
# Processing Record 6 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 7 of Set 6 | kaitangata
# Processing Record 8 of Set 6 | vila velha
# Processing Record 9 of Set 6 | pacific grove
# Processing Record 10 of Set 6 | cidreira
# Processing Record 11 of Set 6 | vila franca do campo
# Processing Record 12 of Set 6 | mitu
# Processing Record 13 of Set 6 | ippy
# Processing Record 14 of Set 6 | samdari
# Processing Record 15 of Set 6 | ojinaga
# Processing Record 16 of Set 6 | rundu
# Processing Record 17 of Set 6 | broome
# Processing Record 18 of Set 6 | tocopilla
# Processing Record 19 of Set 6 | vanimo
# Processing Record 20 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 21 of Set 6 | raudeberg
# Processing Record 22 of Set 6 | hutchinson
# Processing Record 23 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 24 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 6 | jibuti
# Processing Record 26 of Set 6 | saskylakh
# Processing Record 27 of Set 6 | colares
# Processing Record 28 of Set 6 | preili
# Processing Record 29 of Set 6 | moindou
# Processing Record 30 of Set 6 | bubaque
# Processing Record 31 of Set 6 | itarema
# Processing Record 32 of Set 6 | clarence town
# Processing Record 33 of Set 6 | arlit
# Processing Record 34 of Set 6 | ivaipora
# Processing Record 35 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 6 | port macquarie
# Processing Record 37 of Set 6 | wuning
# Processing Record 38 of Set 6 | kilindoni
# Processing Record 39 of Set 6 | coffs harbour
# Processing Record 40 of Set 6 | padang
# Processing Record 41 of Set 6 | aklavik
# Processing Record 42 of Set 6 | marinette
# Processing Record 43 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 44 of Set 6 | bara
# Processing Record 45 of Set 6 | berlevag
# Processing Record 46 of Set 6 | lerwick
# Processing Record 47 of Set 6 | teeli
# Processing Record 48 of Set 6 | kirksville
# Processing Record 49 of Set 6 | esperance
# Processing Record 50 of Set 6 | springfield
# Processing Record 1 of Set 7 | baglan
# Processing Record 2 of Set 7 | port shepstone
# Processing Record 3 of Set 7 | sioux lookout
# Processing Record 4 of Set 7 | shirokiy
# Processing Record 5 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 7 | mufumbwe
# Processing Record 7 of Set 7 | tiksi
# Processing Record 8 of Set 7 | deer lake
# Processing Record 9 of Set 7 | rocky mountain house
# Processing Record 10 of Set 7 | abu samrah
# Processing Record 11 of Set 7 | sola
# Processing Record 12 of Set 7 | brazzaville
# Processing Record 13 of Set 7 | katsuura
# Processing Record 14 of Set 7 | okahandja
# Processing Record 15 of Set 7 | arenapolis
# Processing Record 16 of Set 7 | paamiut
# Processing Record 17 of Set 7 | acapulco
# Processing Record 18 of Set 7 | nanortalik
# Processing Record 19 of Set 7 | ust-kulom
# Processing Record 20 of Set 7 | waipawa
# Processing Record 21 of Set 7 | toledo
# Processing Record 22 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 7 | puerto escondido
# Processing Record 24 of Set 7 | ahipara
# Processing Record 25 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 7 | nome
# Processing Record 27 of Set 7 | masunga
# Processing Record 28 of Set 7 | portland
# Processing Record 29 of Set 7 | pedasi
# Processing Record 30 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 7 | guerrero negro
# Processing Record 32 of Set 7 | darab
# Processing Record 33 of Set 7 | victoria
# Processing Record 34 of Set 7 | bulolo
# Processing Record 35 of Set 7 | mazamari
# Processing Record 36 of Set 7 | coihaique
# Processing Record 37 of Set 7 | kitimat
# Processing Record 38 of Set 7 | tomatlan
# Processing Record 39 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 7 | kodinsk
# Processing Record 41 of Set 7 | morro bay
# Processing Record 42 of Set 7 | chapais
# Processing Record 43 of Set 7 | kangaatsiaq
# Processing Record 44 of Set 7 | khani
# Processing Record 45 of Set 7 | pyapon
# Processing Record 46 of Set 7 | dhidhdhoo
# Processing Record 47 of Set 7 | gazojak
# Processing Record 48 of Set 7 | russell
# Processing Record 49 of Set 7 | hit
# Processing Record 50 of Set 7 | alekseyevsk
# Processing Record 1 of Set 8 | sioux falls
# Processing Record 2 of Set 8 | grindavik
# Processing Record 3 of Set 8 | puerto cabezas
# Processing Record 4 of Set 8 | bordei verde
# Processing Record 5 of Set 8 | shanhetun
# Processing Record 6 of Set 8 | makakilo city
# Processing Record 7 of Set 8 | tautira
# Processing Record 8 of Set 8 | sorland
# Processing Record 9 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 10 of Set 8 | batemans bay
# Processing Record 11 of Set 8 | itacoatiara
# Processing Record 12 of Set 8 | sao jose da coroa grande
# Processing Record 13 of Set 8 | mayo
# Processing Record 14 of Set 8 | yekaterinovka
# Processing Record 15 of Set 8 | saint-joseph
# Processing Record 16 of Set 8 | airai
# Processing Record 17 of Set 8 | honiara
# Processing Record 18 of Set 8 | pacifica
# Processing Record 19 of Set 8 | sept-iles
# Processing Record 20 of Set 8 | meulaboh
# Processing Record 21 of Set 8 | road town
# Processing Record 22 of Set 8 | vardo
# Processing Record 23 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 8 | stornoway
# Processing Record 25 of Set 8 | praya
# Processing Record 26 of Set 8 | soyo
# Processing Record 27 of Set 8 | marsh harbour
# Processing Record 28 of Set 8 | alta floresta
# Processing Record 29 of Set 8 | egvekinot
# Processing Record 30 of Set 8 | salalah
# Processing Record 31 of Set 8 | yulara
# Processing Record 32 of Set 8 | kununurra
# Processing Record 33 of Set 8 | port hardy
# Processing Record 34 of Set 8 | zhanakorgan
# Processing Record 35 of Set 8 | traverse city
# Processing Record 36 of Set 8 | de-kastri
# Processing Record 37 of Set 8 | alamos
# Processing Record 38 of Set 8 | olafsvik
# Processing Record 39 of Set 8 | pandan
# Processing Record 40 of Set 8 | bastia
# Processing Record 41 of Set 8 | acarau
# Processing Record 42 of Set 8 | saint quentin
# City not found. Skipping...
# Processing Record 43 of Set 8 | mhlume
# Processing Record 44 of Set 8 | oussouye
# Processing Record 45 of Set 8 | yerbogachen
# Processing Record 46 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 48 of Set 8 | chiredzi
# Processing Record 49 of Set 8 | hisai
# Processing Record 50 of Set 8 | lorengau
# Processing Record 1 of Set 9 | tabou
# Processing Record 2 of Set 9 | maniitsoq
# Processing Record 3 of Set 9 | yantal
# Processing Record 4 of Set 9 | pinhao
# Processing Record 5 of Set 9 | caramay
# Processing Record 6 of Set 9 | vao
# Processing Record 7 of Set 9 | buraydah
# Processing Record 8 of Set 9 | rio branco
# Processing Record 9 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 9 | sakaiminato
# Processing Record 11 of Set 9 | guanica
# Processing Record 12 of Set 9 | kitale
# Processing Record 13 of Set 9 | kamra
# Processing Record 14 of Set 9 | aquiraz
# Processing Record 15 of Set 9 | mosetse
# Processing Record 16 of Set 9 | bhadrak
# Processing Record 17 of Set 9 | livingston
# Processing Record 18 of Set 9 | aketi
# Processing Record 19 of Set 9 | tazovskiy
# Processing Record 20 of Set 9 | redondela
# Processing Record 21 of Set 9 | svolvaer
# Processing Record 22 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 9 | bac lieu
# Processing Record 24 of Set 9 | vangaindrano
# Processing Record 25 of Set 9 | saqqez
# Processing Record 26 of Set 9 | chapleau
# Processing Record 27 of Set 9 | beian
# Processing Record 28 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 29 of Set 9 | beringovskiy
# Processing Record 30 of Set 9 | leningradskiy
# Processing Record 31 of Set 9 | mirnyy
# Processing Record 32 of Set 9 | brokopondo
# Processing Record 33 of Set 9 | lingyuan
# Processing Record 34 of Set 9 | back mountain
# Processing Record 35 of Set 9 | mahibadhoo
# Processing Record 36 of Set 9 | srednekolymsk
# Processing Record 37 of Set 9 | souillac
# Processing Record 38 of Set 9 | tadine
# Processing Record 39 of Set 9 | celestun
# Processing Record 40 of Set 9 | berbera
# Processing Record 41 of Set 9 | balurghat
# Processing Record 42 of Set 9 | iqaluit
# Processing Record 43 of Set 9 | bereda
# Processing Record 44 of Set 9 | lexington
# Processing Record 45 of Set 9 | diamantino
# Processing Record 46 of Set 9 | calbuco
# Processing Record 47 of Set 9 | millinocket
# Processing Record 48 of Set 9 | maltahohe
# Processing Record 49 of Set 9 | coahuayana
# Processing Record 50 of Set 9 | shatalovo
# Processing Record 1 of Set 10 | port lincoln
# Processing Record 2 of Set 10 | komsomolets
# Processing Record 3 of Set 10 | kirkuk
# Processing Record 4 of Set 10 | boa vista
# Processing Record 5 of Set 10 | turkistan
# Processing Record 6 of Set 10 | ucluelet
# Processing Record 7 of Set 10 | haysville
# Processing Record 8 of Set 10 | aykhal
# Processing Record 9 of Set 10 | bolivar
# Processing Record 10 of Set 10 | rubbestadneset
# Processing Record 11 of Set 10 | morant bay
# Processing Record 12 of Set 10 | san rafael del sur
# Processing Record 13 of Set 10 | shingu
# Processing Record 14 of Set 10 | kodiak
# Processing Record 15 of Set 10 | arrecife
# Processing Record 16 of Set 10 | mackay
# Processing Record 17 of Set 10 | koslan
# Processing Record 18 of Set 10 | haines junction
# Processing Record 19 of Set 10 | ape
# Processing Record 20 of Set 10 | cutervo
# Processing Record 21 of Set 10 | zaysan
# Processing Record 22 of Set 10 | chokurdakh
# Processing Record 23 of Set 10 | alappuzha
# Processing Record 24 of Set 10 | hasaki
# Processing Record 25 of Set 10 | chicama
# Processing Record 26 of Set 10 | pontianak
# Processing Record 27 of Set 10 | dakar
# Processing Record 28 of Set 10 | villiers
# Processing Record 29 of Set 10 | krasnoselkup
# Processing Record 30 of Set 10 | tromso
# Processing Record 31 of Set 10 | westport
# Processing Record 32 of Set 10 | jimenez
# Processing Record 33 of Set 10 | lensk
# Processing Record 34 of Set 10 | paris
# Processing Record 35 of Set 10 | isiro
# Processing Record 36 of Set 10 | rincon
# Processing Record 37 of Set 10 | vilhena
# Processing Record 38 of Set 10 | gacko
# Processing Record 39 of Set 10 | bathsheba
# Processing Record 40 of Set 10 | oskarshamn
# Processing Record 41 of Set 10 | zeya
# Processing Record 42 of Set 10 | kavaratti
# Processing Record 43 of Set 10 | kalmunai
# Processing Record 44 of Set 10 | cooma
# Processing Record 45 of Set 10 | haukipudas
# Processing Record 46 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 47 of Set 10 | asaba
# Processing Record 48 of Set 10 | talnakh
# Processing Record 49 of Set 10 | bowen
# Processing Record 50 of Set 10 | lamar
# Processing Record 1 of Set 11 | shenzhen
# Processing Record 2 of Set 11 | arman
# Processing Record 3 of Set 11 | dongfeng
# Processing Record 4 of Set 11 | adrar
# Processing Record 5 of Set 11 | phek
# Processing Record 6 of Set 11 | arcachon
# Processing Record 7 of Set 11 | bhadra
# Processing Record 8 of Set 11 | warrnambool
# Processing Record 9 of Set 11 | sault sainte marie
# Processing Record 10 of Set 11 | antofagasta
# Processing Record 11 of Set 11 | zalesovo
# Processing Record 12 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 11 | tombouctou
# Processing Record 14 of Set 11 | novyy urengoy
# Processing Record 15 of Set 11 | constitucion
# Processing Record 16 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 11 | aksarka
# Processing Record 18 of Set 11 | santa rosa
# Processing Record 19 of Set 11 | acheng
# Processing Record 20 of Set 11 | dzilam gonzalez
# Processing Record 21 of Set 11 | kousseri
# Processing Record 22 of Set 11 | bilma
# Processing Record 23 of Set 11 | korla
# Processing Record 24 of Set 11 | kovdor
# Processing Record 25 of Set 11 | kabalo
# Processing Record 26 of Set 11 | staryy krym
# Processing Record 27 of Set 11 | atbasar
# Processing Record 28 of Set 11 | nixa
# Processing Record 29 of Set 11 | san carlos de bariloche
# Processing Record 30 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 11 | alim
# Processing Record 32 of Set 11 | loa janan
# Processing Record 33 of Set 11 | zaragoza
# Processing Record 34 of Set 11 | margherita
# Processing Record 35 of Set 11 | salta
# Processing Record 36 of Set 11 | natchez
# Processing Record 37 of Set 11 | asosa
# Processing Record 38 of Set 11 | knysna
# Processing Record 39 of Set 11 | xapuri
# Processing Record 40 of Set 11 | ndola
# Processing Record 41 of Set 11 | takob
# City not found. Skipping...
# Processing Record 42 of Set 11 | andrelandia
# Processing Record 43 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 11 | bandarbeyla
# Processing Record 46 of Set 11 | klaksvik
# Processing Record 47 of Set 11 | hastings
# Processing Record 48 of Set 11 | cuamba
# Processing Record 49 of Set 11 | palmer
# Processing Record 50 of Set 11 | eureka
# Processing Record 1 of Set 12 | motihari
# Processing Record 2 of Set 12 | qaqortoq
# Processing Record 3 of Set 12 | hakone
# Processing Record 4 of Set 12 | vitim
# Processing Record 5 of Set 12 | ercis
# Processing Record 6 of Set 12 | ust-tsilma
# Processing Record 7 of Set 12 | tucupita
# Processing Record 8 of Set 12 | kapuskasing
# Processing Record 9 of Set 12 | laredo
# Processing Record 10 of Set 12 | coldwater
# Processing Record 11 of Set 12 | rongcheng
# Processing Record 12 of Set 12 | hambantota
# Processing Record 13 of Set 12 | petrivka
# Processing Record 14 of Set 12 | bambanglipuro
# Processing Record 15 of Set 12 | markala
# Processing Record 16 of Set 12 | stekolnyy
# City not found. Skipping...
# Processing Record 17 of Set 12 | roseto degli abruzzi
# Processing Record 18 of Set 12 | abhayapuri
# Processing Record 19 of Set 12 | whitianga
# Processing Record 20 of Set 12 | sinaloa
# Processing Record 21 of Set 12 | amahai
# Processing Record 22 of Set 12 | palana
# Processing Record 23 of Set 12 | kollam
# Processing Record 24 of Set 12 | altamira
# Processing Record 25 of Set 12 | damara
# Processing Record 26 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 12 | hualmay
# Processing Record 28 of Set 12 | linguere
# Processing Record 29 of Set 12 | atyrau
# Processing Record 30 of Set 12 | roald
# Processing Record 31 of Set 12 | longjiang
# Processing Record 32 of Set 12 | kotar
# Processing Record 33 of Set 12 | ilhabela
# Processing Record 34 of Set 12 | kahului
# Processing Record 35 of Set 12 | birao
# Processing Record 36 of Set 12 | kandi
# Processing Record 37 of Set 12 | daru
# Processing Record 38 of Set 12 | khasan
# Processing Record 39 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 12 | dunedin
# Processing Record 41 of Set 12 | muravlenko
# Processing Record 42 of Set 12 | maragogi
# Processing Record 43 of Set 12 | vostochnyy
# Processing Record 44 of Set 12 | talaya
# Processing Record 45 of Set 12 | wlodawa
# Processing Record 46 of Set 12 | pathein
# Processing Record 47 of Set 12 | palu
# Processing Record 48 of Set 12 | huarmey
# Processing Record 49 of Set 12 | sokolo
# Processing Record 50 of Set 12 | kudinovo
# Processing Record 1 of Set 13 | syracuse
# Processing Record 2 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 13 | gorbatov
# Processing Record 4 of Set 13 | hurricane
# Processing Record 5 of Set 13 | imbituba
# Processing Record 6 of Set 13 | muskogee
# Processing Record 7 of Set 13 | kenai
# Processing Record 8 of Set 13 | misratah
# Processing Record 9 of Set 13 | agadez
# Processing Record 10 of Set 13 | shar
# Processing Record 11 of Set 13 | chegdomyn
# Processing Record 12 of Set 13 | along
# Processing Record 13 of Set 13 | niono
# Processing Record 14 of Set 13 | dong hoi
# Processing Record 15 of Set 13 | touros
# Processing Record 16 of Set 13 | yokadouma
# Processing Record 17 of Set 13 | igrim
# Processing Record 18 of Set 13 | faya
# Processing Record 19 of Set 13 | shiyan
# Processing Record 20 of Set 13 | san carlos
# Processing Record 21 of Set 13 | francisco sa
# Processing Record 22 of Set 13 | te anau
# Processing Record 23 of Set 13 | leshukonskoye
# Processing Record 24 of Set 13 | tottori
# Processing Record 25 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 26 of Set 13 | oda
# Processing Record 27 of Set 13 | urumqi
# Processing Record 28 of Set 13 | bayan
# Processing Record 29 of Set 13 | opuwo
# Processing Record 30 of Set 13 | henties bay
# Processing Record 31 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 13 | peno
# Processing Record 33 of Set 13 | whitehorse
# Processing Record 34 of Set 13 | pemangkat
# Processing Record 35 of Set 13 | goderich
# Processing Record 36 of Set 13 | pisco
# Processing Record 37 of Set 13 | strezhevoy
# Processing Record 38 of Set 13 | baghdad
# Processing Record 39 of Set 13 | didsbury
# Processing Record 40 of Set 13 | birjand
# Processing Record 41 of Set 13 | cabedelo
# Processing Record 42 of Set 13 | mamakan
# Processing Record 43 of Set 13 | kimbe
# Processing Record 44 of Set 13 | noumea
# Processing Record 45 of Set 13 | tra vinh
# Processing Record 46 of Set 13 | orodara
# Processing Record 47 of Set 13 | ternate
# Processing Record 48 of Set 13 | glenwood springs
# Processing Record 49 of Set 13 | udachnyy
# Processing Record 50 of Set 13 | dali
# Processing Record 1 of Set 14 | lata
# Processing Record 2 of Set 14 | edeia
# Processing Record 3 of Set 14 | tiznit
# Processing Record 4 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 5 of Set 14 | ossora
# Processing Record 6 of Set 14 | fort morgan
# Processing Record 7 of Set 14 | great yarmouth
# Processing Record 8 of Set 14 | donskoye
# Processing Record 9 of Set 14 | chitral
# Processing Record 10 of Set 14 | wum
# Processing Record 11 of Set 14 | sarmizegetusa
# Processing Record 12 of Set 14 | nanchong
# Processing Record 13 of Set 14 | kloulklubed
# Processing Record 14 of Set 14 | tintigny
# Processing Record 15 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 16 of Set 14 | juegang
# Processing Record 17 of Set 14 | loandjili
# Processing Record 18 of Set 14 | owando
# Processing Record 19 of Set 14 | samarai
# Processing Record 20 of Set 14 | tres lagoas
# Processing Record 21 of Set 14 | tilichiki
# Processing Record 22 of Set 14 | turukhansk
# Processing Record 23 of Set 14 | rehoboth
# Processing Record 24 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 25 of Set 14 | xiongzhou
# Processing Record 26 of Set 14 | inirida
# Processing Record 27 of Set 14 | kampong thum
# Processing Record 28 of Set 14 | santa cruz
# Processing Record 29 of Set 14 | gat
# Processing Record 30 of Set 14 | nizwa
# Processing Record 31 of Set 14 | terrace
# Processing Record 32 of Set 14 | krutikha
# Processing Record 33 of Set 14 | le vauclin
# Processing Record 34 of Set 14 | alyangula
# Processing Record 35 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 14 | tucurui
# Processing Record 37 of Set 14 | nanakuli
# Processing Record 38 of Set 14 | melendugno
# Processing Record 39 of Set 14 | wuwei
# Processing Record 40 of Set 14 | katima mulilo
# Processing Record 41 of Set 14 | borogontsy
# Processing Record 42 of Set 14 | america dourada
# Processing Record 43 of Set 14 | antsohihy
# Processing Record 44 of Set 14 | vestmannaeyjar
# Processing Record 45 of Set 14 | talcahuano
# Processing Record 46 of Set 14 | mengen
# Processing Record 47 of Set 14 | dongsheng
# Processing Record 48 of Set 14 | shizunai
# Processing Record 49 of Set 14 | obo
# Processing Record 50 of Set 14 | ponta delgada
# Processing Record 1 of Set 15 | san pedro
# Processing Record 2 of Set 15 | bontang
# Processing Record 3 of Set 15 | rehlingen-siersburg
# Processing Record 4 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 15 | odweyne
# Processing Record 6 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 7 of Set 15 | teguise
# Processing Record 8 of Set 15 | suntar
# Processing Record 9 of Set 15 | lefka
# Processing Record 10 of Set 15 | wolfsberg
# Processing Record 11 of Set 15 | bad liebenwerda
# Processing Record 12 of Set 15 | horadiz
# Processing Record 13 of Set 15 | changji
# Processing Record 14 of Set 15 | sarmanovo
# Processing Record 15 of Set 15 | hamilton
# Processing Record 16 of Set 15 | barcelos
# Processing Record 17 of Set 15 | toktogul
# Processing Record 18 of Set 15 | manzhouli
# Processing Record 19 of Set 15 | morondava
# Processing Record 20 of Set 15 | camacha
# Processing Record 21 of Set 15 | kargasok
# Processing Record 22 of Set 15 | mnogovershinnyy
# Processing Record 23 of Set 15 | brae
# Processing Record 24 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 15 | meadow lake
# Processing Record 26 of Set 15 | doha
# Processing Record 27 of Set 15 | zelenoborskiy
# Processing Record 28 of Set 15 | jiroft
# City not found. Skipping...
# Processing Record 29 of Set 15 | filadelfia
# Processing Record 30 of Set 15 | umm kaddadah
# Processing Record 31 of Set 15 | gizo
# Processing Record 32 of Set 15 | liverpool
# Processing Record 33 of Set 15 | tingrela
# City not found. Skipping...
# Processing Record 34 of Set 15 | kapit
# Processing Record 35 of Set 15 | cape girardeau
# Processing Record 36 of Set 15 | povenets
# Processing Record 37 of Set 15 | sigli
# Processing Record 38 of Set 15 | colesberg
# Processing Record 39 of Set 15 | coulihaut
# City not found. Skipping...
# Processing Record 40 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 15 | kochevo
# Processing Record 42 of Set 15 | toguchin
# Processing Record 43 of Set 15 | kralendijk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Get the JSON text of the 'Get' request.
#city_weather.json()

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Albany      US  42.6001  -73.9662     64.81        29          59
# 1       Kaseda      JP  31.4167  130.3167     57.83        54          84
# 2   Sao Filipe      CV  14.8961  -24.4956     71.06        78           4
# 3  Pangnirtung      CA  66.1451  -65.7125     -0.40        71           0
# 4         Pout      SN  14.7739  -17.0603     67.98        94          40
# 5      Salinas      US  36.6777 -121.6555     73.99        58           0
# 6        Gimli      CA  50.6336  -96.9907     21.22        53         100
# 7       Atuona      PF  -9.8000 -139.0333     79.00        78          19
# 8       Muisne      EC   0.6000  -80.0333     76.84        86          96
# 9         Tura      IN  25.5198   90.2201     73.76        93          70
#
#    Wind Speed Current Description
# 0        5.01       broken clouds
# 1       16.22       broken clouds
# 2        8.79           clear sky
# 3        3.44           clear sky
# 4       12.66    scattered clouds
# 5       19.57           clear sky
# 6       14.97     overcast clouds
# 7       15.43          light rain
# 8        7.99     overcast clouds
# 9       10.22       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/challenge_cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df.to_csv(path_or_buf='../Weather_Database/WeatherPy_Database.csv', index_label='City_ID')
